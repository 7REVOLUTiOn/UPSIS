# %% [markdown]
# <a href="https://colab.research.google.com/github/7REVOLUTiOn/UPSIS/blob/main/%D0%A3%D0%9F%D0%98%D0%A1_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%961_%D0%9E%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BA%D0%BE%D0%BD%D1%86%D0%B5%D0%BF%D1%82%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%BE%D1%81%D0%BD%D0%BE%D0%B2_%D0%B4%D0%B8%D0%BF%D0%BB%D0%BE%D0%BC%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82%D0%B0_%D0%B2_%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D0%B8_%D0%B8%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D1%85_%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание №1. Определение концептуальных основ дипломного проекта в области информационных систем**

# %% [markdown]
# В рамках дисциплины "Управление проектами информационных систем" представьте развернутое концептуальное обоснование вашего проекта, ответив на следующие вопросы:

# %% [markdown]
# #### **1. Обоснование необходимости разработки**

# %% [markdown]
# Для кого предназначено разрабатываемое Вами решение и какие потребности целевой аудитории оно призвано удовлетворить?

# %% [markdown]
# *Обоснуйте актуальность решаемой проблемы для конкретных заинтересованных сторон.*

# %% [markdown]
# Во первых, культурные учреждения - для создания тактильных экспонатов на основе картин и фотографий.
# Во вторых, люди с нарушениями зрения - для получения доступа к визуальным предметам искусства через ощупь.
# В третьих, любители 3D-печати - для быстрой конвертации 2D-обьекта (арта) в объемные модели без навыков 3D моделирования.
#
# Существует проблема недоступности визуального искусства для незрячих людей. Ручное создание 3D-моделей по картинам требует высоких затрат времени и квалификации. Разрабатываемое решение автоматизирует процесс перевода 2D-изображения в 3D-форму, снижая стоимость и время производства таких предметов. В современном мире, с распостранненой 3д печатью или слепыми людьми должнен быть удобный инструмент c открытым исходным кодом, позволяющий выполнять данную работу.

# %% [markdown]
# ---

# %% [markdown]
# #### **2. Ожидаемые результаты проекта**

# %% [markdown]
# Опишите конкретные результаты, которые планируется получить по завершении проекта. Какой программный продукт, методика или информационная система будет создан/создана в результате вашей работы?

# %% [markdown]
# По завершении проекта будет создан веб-сервис для автоматической генерации 3D-моделей по 2D обьектам.
#
# Конкретные результаты:
# Сравнительный анализ архитектур: Отчет с оценкой моделей (MiDaS, DepthAnything, NeRF, Unet) по метрикам SSIM, L1-loss, Depth smoothness, а также по вычислительной сложности (Params, FLOPs, вес модели).
# Алгоритм конвертации: Реализованный метод преобразования карты глубины (numpy-массив) в полигональную сетку (mesh) с экспортом в формат STL.
# Модуль постобработки: Набор методов фильтрации топологии (удаление шумов, сглаживание, редукция лишних граней) для обеспечения пригодности модели к 3D-печати.
# Верифицированный датасет: Подборка старинных фотографий и картин для тестирования качества реконструкции.
# Рабочий прототип: Веб-интерфейс, принимающий изображение и выдающий готовый к печати STL-файл.

# %% [markdown]
# ---

# %% [markdown]
# #### **3. Методология использования**

# %% [markdown]
# Каким образом предполагается практическое применение разрабатываемого решения? Опишите основные сценарии взаимодействия пользователей с разрабатываемым решением.

# %% [markdown]
# Загрузка: Пользователь заходит на веб-ресурс и загружает 2D-изображение (картина, фотография) в стандартном формате (JPG/PNG).
# Обработка: Система на сервере пропускает изображение через выбранную модель оценки глубины (Monocular Depth Estimation), генерирует карту глубины и преобразует её в 3D-меш.
# Фильтрация: Автоматически применяются алгоритмы сглаживания и оптимизации топологии согласно требованиям к 3D-печати (толщина стенок, отсутствие артефактов).
# Получение результата: Пользователь скачивает файл в формате STL.
# Использование: Файл открывается в слайсере (для печати) или в CAD-редакторе (Blender/MeshLab/FreeCAD) для дальнейшей доработки.

# %% [markdown]
# ---

# %% [markdown]
# #### **4. Входные данные и их источники**

# %% [markdown]
# Какие типы данных будут использоваться в качестве входных данных для вашего решения? В каком формате они будут представлены и из каких источников планируется их получение?

# %% [markdown]
# Типы данных:
# Растровые двумерные изображения (RGB).
# Гиперпараметры генерации (опционально: желаемая глубина рельефа, уровень детализации).
#
# Формат:
# Изображения: .jpg, .png.
#
# Источники:
# Пользовательский ввод: Файлы, загружаемые через интерфейс веб-сервиса.

# %% [markdown]
# ---

# %% [markdown]
# #### **5. Выходные данные и практическая значимость**

# %% [markdown]
# Какие результаты будет формировать Ваше решение на выходе?

# %% [markdown]
# Выходные данные:
# Файл 3D-модели в формате STL, готовый к передаче в слайсер.
# Визуализация карты глубины (опционально, для контроля качества).

# %% [markdown]
# ---

# %% [markdown]
# Опишите конкретно и без "воды" пользу (практическую ценность), которую заинтересованные стороны получат от использования этих результатов.

# %% [markdown]
# Доступность: Возможность для незрячих людей уведить картину через осязание.
# Экономия ресурсов: Сокращение времени подготовки тактильного экспоната с нескольких дней/недель при ручном моделирование или другой работы до нескольких минут.
# Техническая готовность: Выходные STL-файлы проходят предварительную топологическую оптимизацию, что минимизирует брак при 3D-печати.
# Создание физических копий картин, устойчивых к времени и пригодных для тактильного изучения.

# %% [markdown]
# ---
